# %%
! python src/pothole/evaluate.py --weights checkpoints/yolov8n_best.onnx --data data/data.yaml --split test --device cuda
# Out:
# ...
#       POTHOLE DETECTION MODEL EVALUATION
# ...
# [*] Loading model from: checkpoints/yolov8n_best.onnx
# WARNING Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# [*] Starting evaluation on split: TEST
# [*] Image size: 640x640 | Batch size: 16
# Ultralytics 8.4.54  Python-3.11.9 torch-2.11.0+cu128 CUDA:0 (NVIDIA GeForce RTX 5070 Ti, 16303MiB)
# Loading checkpoints/yolov8n_best.onnx for ONNX Runtime inference...
# WARNING CUDA requested but CUDAExecutionProvider not available. Using CPU...
# Using ONNX Runtime 1.26.0 with CPUExecutionProvider
# Setting batch=1 input of shape (1, 3, 640, 640)
# val: Fast image access  (ping: 0.00.0 ms, read: 810.6329.4 MB/s, size: 45.0 KB)
#
# val: Scanning D:\MET EV\Potholes Detection\data\test\labels.cache... 285 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 285/285  0.0s
#
# ...

# %%
! python src/pipeline/run_full_pipeline.py --source test.jpg --yolo-weights checkpoints/yolov8n_best.onnx --depth-weights  checkpoints/depth_anything_v2_vits_dynamic.onnx --depth-size 140 --camera-height 0.644 --pitch 33.18 --fov 110 --show
# Out:
# [*] Loading Models...
# WARNING Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# [*] Reading static image: test.jpg
# [*] Starting inference on image...
# [*] Camera Config: Height=0.644m, Pitch=33.18°, FOV=110.0°
# [*] Depth model input size: 140x140
# Loading checkpoints/yolov8n_best.onnx for ONNX Runtime inference...
# WARNING CUDA requested but CUDAExecutionProvider not available. Using CPU...
# Using ONNX Runtime 1.26.0 with CPUExecutionProvider
#  ➢ Processing finished in 122.8 ms
#
# [✔] Inference complete! Output saved to: runs/inference_pipeline\pipeline_test.jpg
# [*] Press any key to close the window...

# %%
! python src/pipeline/run_full_pipeline.py --source source_video/demo_origin.mp4 --yolo-weights checkpoints/yolov8n_best.onnx --depth-weights  checkpoints/depth_anything_v2_vits_dynamic.onnx --depth-size 140 --camera-height 0.646 --pitch 33.18 --fov 110 --show
# Out:
# [*] Loading Models...
# WARNING Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# [*] Starting inference... Press 'q' to stop.
# [*] Camera Config: Height=0.646m, Pitch=33.18°, FOV=110.0°
# [*] Depth model input size: 140x140
# Loading checkpoints/yolov8n_best.onnx for ONNX Runtime inference...
# WARNING CUDA requested but CUDAExecutionProvider not available. Using CPU...
# Using ONNX Runtime 1.26.0 with CPUExecutionProvider
#  ➢ Processed frame 10, Speed: 18.5 FPS
#  ➢ Processed frame 20, Speed: 18.6 FPS
#  ➢ Processed frame 30, Speed: 18.6 FPS
#  ➢ Processed frame 40, Speed: 18.0 FPS
#  ➢ Processed frame 50, Speed: 17.8 FPS
#  ➢ Processed frame 60, Speed: 18.4 FPS
#  ➢ Processed frame 70, Speed: 18.6 FPS
#  ➢ Processed frame 80, Speed: 18.5 FPS
#  ➢ Processed frame 90, Speed: 18.5 FPS
#  ➢ Processed frame 100, Speed: 18.4 FPS
#  ➢ Processed frame 110, Speed: 18.4 FPS
# ...
